# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://i.imgur.com/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss = 'binary_crossentropy',
    metrics = ['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 44s 421ms/step - loss: 0.6796 - binary_accuracy: 0.5773 - val_loss: 0.6680 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6675 - binary_accuracy: 0.5787 - val_loss: 0.6628 - val_binary_accuracy: 0.5785
# Epoch 3/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6629 - binary_accuracy: 0.5787 - val_loss: 0.6563 - val_binary_accuracy: 0.5785
# Epoch 4/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6611 - binary_accuracy: 0.5787 - val_loss: 0.6535 - val_binary_accuracy: 0.5785
# Epoch 5/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6571 - binary_accuracy: 0.5998 - val_loss: 0.6509 - val_binary_accuracy: 0.6058
# Epoch 6/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6513 - binary_accuracy: 0.6168 - val_loss: 0.6429 - val_binary_accuracy: 0.6278
# Epoch 7/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6451 - binary_accuracy: 0.6240 - val_loss: 0.6371 - val_binary_accuracy: 0.6349
# Epoch 8/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6403 - binary_accuracy: 0.6346 - val_loss: 0.6329 - val_binary_accuracy: 0.6379
# Epoch 9/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6343 - binary_accuracy: 0.6404 - val_loss: 0.6269 - val_binary_accuracy: 0.6535
# Epoch 10/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6274 - binary_accuracy: 0.6459 - val_loss: 0.6267 - val_binary_accuracy: 0.6535
# Epoch 11/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6216 - binary_accuracy: 0.6656 - val_loss: 0.6135 - val_binary_accuracy: 0.6676
# Epoch 12/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6122 - binary_accuracy: 0.6748 - val_loss: 0.6075 - val_binary_accuracy: 0.6690
# Epoch 13/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6026 - binary_accuracy: 0.6858 - val_loss: 0.6041 - val_binary_accuracy: 0.6648
# Epoch 14/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5993 - binary_accuracy: 0.6955 - val_loss: 0.5956 - val_binary_accuracy: 0.6921
# Epoch 15/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5928 - binary_accuracy: 0.6916 - val_loss: 0.5924 - val_binary_accuracy: 0.7001
# Epoch 16/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5755 - binary_accuracy: 0.7139 - val_loss: 0.5639 - val_binary_accuracy: 0.7088
# Epoch 17/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5660 - binary_accuracy: 0.7327 - val_loss: 0.5658 - val_binary_accuracy: 0.7206
# Epoch 18/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5399 - binary_accuracy: 0.7397 - val_loss: 0.5236 - val_binary_accuracy: 0.7452
# Epoch 19/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5139 - binary_accuracy: 0.7534 - val_loss: 0.4911 - val_binary_accuracy: 0.7688
# Epoch 20/50
# 80/80 [==============================] - 4s 53ms/step - loss: 0.4753 - binary_accuracy: 0.7768 - val_loss: 0.4726 - val_binary_accuracy: 0.7789
# Epoch 21/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4432 - binary_accuracy: 0.7942 - val_loss: 0.4662 - val_binary_accuracy: 0.7866
# Epoch 22/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4149 - binary_accuracy: 0.8114 - val_loss: 0.4731 - val_binary_accuracy: 0.7852
# Epoch 23/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3955 - binary_accuracy: 0.8192 - val_loss: 0.4736 - val_binary_accuracy: 0.7676
# Epoch 24/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.3793 - binary_accuracy: 0.8229 - val_loss: 0.4277 - val_binary_accuracy: 0.8066
# Epoch 25/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3542 - binary_accuracy: 0.8347 - val_loss: 0.4938 - val_binary_accuracy: 0.7630
# Epoch 26/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3282 - binary_accuracy: 0.8525 - val_loss: 0.4692 - val_binary_accuracy: 0.7882
# Epoch 27/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.3165 - binary_accuracy: 0.8599 - val_loss: 0.5803 - val_binary_accuracy: 0.7450
# Epoch 28/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3130 - binary_accuracy: 0.8521 - val_loss: 0.4643 - val_binary_accuracy: 0.8066
# Epoch 29/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2768 - binary_accuracy: 0.8714 - val_loss: 0.4474 - val_binary_accuracy: 0.8086
# Epoch 30/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2685 - binary_accuracy: 0.8702 - val_loss: 0.4701 - val_binary_accuracy: 0.8068
# Epoch 31/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2587 - binary_accuracy: 0.8835 - val_loss: 0.4865 - val_binary_accuracy: 0.8113
# Epoch 32/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2708 - binary_accuracy: 0.8738 - val_loss: 0.4823 - val_binary_accuracy: 0.8151
# Epoch 33/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2424 - binary_accuracy: 0.8874 - val_loss: 0.5080 - val_binary_accuracy: 0.8089
# Epoch 34/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.2217 - binary_accuracy: 0.8994 - val_loss: 0.6823 - val_binary_accuracy: 0.7676
# Epoch 35/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2162 - binary_accuracy: 0.8970 - val_loss: 0.6021 - val_binary_accuracy: 0.7985
# Epoch 36/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1911 - binary_accuracy: 0.9130 - val_loss: 0.7531 - val_binary_accuracy: 0.7979
# Epoch 37/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1812 - binary_accuracy: 0.9185 - val_loss: 0.8526 - val_binary_accuracy: 0.7899
# Epoch 38/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1719 - binary_accuracy: 0.9238 - val_loss: 0.7415 - val_binary_accuracy: 0.7979
# Epoch 39/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1656 - binary_accuracy: 0.9238 - val_loss: 0.5617 - val_binary_accuracy: 0.8345
# Epoch 40/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1793 - binary_accuracy: 0.9187 - val_loss: 0.8108 - val_binary_accuracy: 0.8036
# Epoch 41/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1894 - binary_accuracy: 0.9140 - val_loss: 0.6255 - val_binary_accuracy: 0.7973
# Epoch 42/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1791 - binary_accuracy: 0.9248 - val_loss: 0.4606 - val_binary_accuracy: 0.8268
# Epoch 43/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1766 - binary_accuracy: 0.9261 - val_loss: 0.4733 - val_binary_accuracy: 0.8266
# Epoch 44/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1679 - binary_accuracy: 0.9246 - val_loss: 0.5533 - val_binary_accuracy: 0.8052
# Epoch 45/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1607 - binary_accuracy: 0.9322 - val_loss: 0.5202 - val_binary_accuracy: 0.8080
# Epoch 46/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1258 - binary_accuracy: 0.9515 - val_loss: 0.6629 - val_binary_accuracy: 0.8099
# Epoch 47/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1206 - binary_accuracy: 0.9470 - val_loss: 0.6267 - val_binary_accuracy: 0.8361
# Epoch 48/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1093 - binary_accuracy: 0.9543 - val_loss: 0.6573 - val_binary_accuracy: 0.8442
# Epoch 49/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1086 - binary_accuracy: 0.9592 - val_loss: 0.6544 - val_binary_accuracy: 0.8414
# Epoch 50/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1013 - binary_accuracy: 0.9594 - val_loss: 0.6464 - val_binary_accuracy: 0.8428

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
